# %%
import sys
import autosklearn.classification

sys.path.append('/media/controlslab/DATA/Projects')

from ann_framework.data_handlers.data_handler_MNIST import MNISTDataHandler

dHandler_mnist = MNISTDataHandler()
dHandler_mnist.load_data(verbose=1, cross_validation_ratio=0.2)
dHandler_mnist.print_data()

example = dHandler_mnist.X_train[0]
print(example.shape)
print(example)

# %%
import sklearn.cross_validation
import sklearn.datasets
import sklearn.metrics
import time
import autosklearn.classification
 
def main():
    digits = sklearn.datasets.load_digits()
    X = digits.data
    y = digits.target
    X_train, X_test, y_train, y_test = \
        sklearn.cross_validation.train_test_split(X, y, random_state=1)
 
    automl = autosklearn.classification.AutoSklearnClassifier()
#         time_left_for_this_task=120, per_run_time_limit=30,
#         tmp_folder='/media/controlslab/DATA/Projects/tmp7/autoslearn_cv_example_tmp',
#         output_folder='/media/controlslab/DATA/Projects/tmp7/autosklearn_cv_example_out'
#         delete_tmp_folder_after_terminate=False,
#         resampling_strategy='cv', resampling_strategy_arguments={'folds': 5}
    
    # fit() changes the data in place, but refit needs the original data. We
    # therefore copy the data. In practice, one should reload the data
    automl.fit(X_train, y_train)
    # During fit(), models are fit on individual cross-validation folds. To use
    # all available data, we call refit() which trains all models in the
    # final ensemble on the whole dataset.
    # automl.refit(X_train.copy(), y_train.copy())
 
    print(automl.show_models())

    train_predictions = automl.predict(X_train)
    print("Training accuracy score", sklearn.metrics.accuracy_score(y_train, train_predictions)
    predictions = automl.predict(X_test)
    print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, predictions))

tic = time.time()
if __name__ == '__main__':
    main()
toc = time.time()  
print(toc - tic)
# Out:
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/pyparsing.py:2910: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile( self.reString )
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# [WARNING] [2019-03-11 22:11:33,953:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# [WARNING] [2019-03-11 22:11:33,957:EnsembleBuilder(1):d74860caaa557f473ce23908ff7ba369] No models better than random - using Dummy Score!
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# /home/controlslab/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/autosklearn/evaluation/train_evaluator.py:197: RuntimeWarning: Mean of empty slice
#   Y_train_pred = np.nanmean(Y_train_pred_full, axis=0)
# ...
#   'target_type': 'classification',
#   'signed': False})),
# (0.020000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'one_hot_encoding', 'classifier:__choice__': 'libsvm_svc', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'normalize', 'categorical_encoding:one_hot_encoding:use_minimum_fraction': 'True', 'classifier:libsvm_svc:C': 0.08022492050398489, 'classifier:libsvm_svc:gamma': 7.683002334430468, 'classifier:libsvm_svc:kernel': 'poly', 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:tol': 0.024555010060043934, 'categorical_encoding:one_hot_encoding:minimum_fraction': 0.010000000000000004, 'classifier:libsvm_svc:coef0': 0.995903986485208, 'classifier:libsvm_svc:degree': 4},
# dataset_properties={
#   'task': 2,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': True,
#   'target_type': 'classification',
#   'signed': False})),
# (0.020000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'libsvm_svc', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'normalize', 'classifier:libsvm_svc:C': 0.08022492050398489, 'classifier:libsvm_svc:gamma': 2.7263279745447915, 'classifier:libsvm_svc:kernel': 'poly', 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:tol': 0.024555010060043934, 'classifier:libsvm_svc:coef0': 0.7411656021269404, 'classifier:libsvm_svc:degree': 5},
# dataset_properties={
#   'task': 2,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': True,
#   'target_type': 'classification',
#   'signed': False})),
# (0.020000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'libsvm_svc', 'imputation:strategy': 'median', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'normalize', 'classifier:libsvm_svc:C': 0.08022492050398489, 'classifier:libsvm_svc:gamma': 3.3075583903661157, 'classifier:libsvm_svc:kernel': 'poly', 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:tol': 0.024555010060043934, 'classifier:libsvm_svc:coef0': 0.3953724586810816, 'classifier:libsvm_svc:degree': 5},
# dataset_properties={
#   'task': 2,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': True,
#   'target_type': 'classification',
#   'signed': False})),
# (0.020000, SimpleClassificationPipeline({'balancing:strategy': 'none', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'libsvm_svc', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'normalize', 'classifier:libsvm_svc:C': 62.13182469940547, 'classifier:libsvm_svc:gamma': 5.352261791775246, 'classifier:libsvm_svc:kernel': 'poly', 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:tol': 1.0091757583925831e-05, 'classifier:libsvm_svc:coef0': 0.7825183406875373, 'classifier:libsvm_svc:degree': 4},
# dataset_properties={
#   'task': 2,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': True,
#   'target_type': 'classification',
#   'signed': False})),
# (0.020000, SimpleClassificationPipeline({'balancing:strategy': 'weighting', 'categorical_encoding:__choice__': 'no_encoding', 'classifier:__choice__': 'libsvm_svc', 'imputation:strategy': 'mean', 'preprocessor:__choice__': 'no_preprocessing', 'rescaling:__choice__': 'normalize', 
 'classifier:libsvm_svc:max_iter': -1, 'classifier:libsvm_svc:shrinking': 'True', 'classifier:libsvm_svc:tol': 5.035652645462338e-05, 'preprocessor:polynomial:degree': 2, 'preprocessor:polynomial:include_bias': 'False', 'preprocessor:polynomial:interaction_only': 'False', 'classifier:libsvm_svc:coef0': -0.4949844653270208, 'classifier:libsvm_svc:degree': 2},
# dataset_properties={
#   'task': 2,
#   'sparse': False,
#   'multilabel': False,
#   'multiclass': True,
#   'target_type': 'classification',
#   'signed': False})),
# ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-28a3be7de4fe> in <module>
#      36 tic = time.time()
#      37 if __name__ == '__main__':
# ---> 38     main()
#      39 toc = time.time()
#      40 print(toc - tic)
#
# <ipython-input-1-28a3be7de4fe> in main()
#      30
#      31     train = automl.predict(X_train)
# ---> 32     print("Training accuracy score", sklearn.metrics.accuracy_score(y_test, train))
#      33     predictions = automl.predict(X_test)
#      34     print("Test accuracy score", sklearn.metrics.accuracy_score(y_test, predictions))
#
# ~/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/sklearn/metrics/classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     if y_type.startswith('multilabel'):
#     178         differing_labels = count_nonzero(y_true - y_pred, axis=1)
#
# ~/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~/anaconda3/envs/tf_cpu/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [450, 1347]

# %%
digits = sklearn.datasets.load_digits()
X = digits.data
y = digits.target
X_train, X_test, y_train, y_test = \
    sklearn.cross_validation.train_test_split(X, y, random_state=1)
print('X_train')
print(X_train)
print('y_train')
print(y_train)
print('X_test')
print(X_test)
print('y_test')
print(y_test)
len(y_train)

# %%
import sys
import autosklearn.classification

sys.path.append('/media/controlslab/DATA/Projects')

from ann_framework.data_handlers.data_handler_MNIST import MNISTDataHandler

dHandler_mnist = MNISTDataHandler()
dHandler_mnist.load_data(verbose=1, cross_validation_ratio=0.2)
# dHandler_mnist.print_data()

# example = dHandler_mnist.X_train[0]
# print(example.shape)
# print(example)

X_train = dHandler_mnist.X_train
y_train = dHandler_mnist.y_train
X_test = dHandler_mnist.X_test
y_test = dHandler_mnist.y_test

print('X_train')
print(X_train)
print('y_train')
print(y_train)
print('X_test')
print(X_test)
print('y_test')
print(y_test)

# %%
X.shape

# %%
X_new = X[0:20,:]
y_new = y[0:20]

# %%
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics

import autosklearn.classification


def main():
    X, y = sklearn.datasets.load_digits(return_X_y=True)
    X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(X, y, random_state=1)

    
    
    automl = autosklearn.classification.AutoSklearnClassifier(
        time_left_for_this_task=120,
        per_run_time_limit=30,
#         tmp_folder='/tmp/autosklearn_cv_example_tmp',
#         output_folder='/tmp/autosklearn_cv_example_out',
#        delete_tmp_folder_after_terminate=False,
#         resampling_strategy='cv',
#         resampling_strategy_arguments={'folds': 5},
        
    )
    

    # fit() changes the data in place, but refit needs the original data. We
    # therefore copy the data. In practice, one should reload the data
    automl.fit(X_train.copy(), y_train.copy(),dataset_name = 'digits')
    # During fit(), models are fit on individual cross-validation folds. To use
    # all available data, we call refit() which trains all models in the
    # final ensemble on the whole dataset.
    # automl.refit(X_train.copy(), y_train.copy())

    print(automl.show_models())

    predictions = automl.predict(X_test)
    print("Accuracy score", sklearn.metrics.accuracy_score(y_test, predictions))


if __name__ == '__main__':
    main()
