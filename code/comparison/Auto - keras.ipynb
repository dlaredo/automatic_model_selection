# %%
import autokeras

# %%
from keras.datasets import mnist
from autokeras.image.image_supervised import ImageClassifier

if __name__ == '__main__':
    (x_train, y_train), (x_test, y_test) = mnist.load_data()
    x_train = x_train.reshape(x_train.shape + (1,))
    x_test = x_test.reshape(x_test.shape + (1,))

    clf = ImageClassifier(verbose=True)
    clf.fit(x_train, y_train, time_limit=4 * 60 * 60)
    clf.final_fit(x_train, y_train, x_test, y_test, retrain=True)
    y = clf.evaluate(x_test, y_test)
    print(y)
# Out:
# Using TensorFlow backend.
# Saving Directory: /tmp/autokeras_N4R5J9
# Preprocessing the images.
# Preprocessing finished.
#
# Initializing search.
# Initialization finished.
#
#
# +----------------------------------------------+
# |               Training model 0               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           0            |   0.3394380159676075   |   0.9735999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 1               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           1            |  0.08150130957365036   |   0.9932000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 2               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           2            |   0.1038620974868536   |         0.9904         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 3               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           3            |  0.09491321258246899   |         0.9924         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 4               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           4            |  0.08946106992661954   |   0.9911999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 5               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           5            |   0.0896423039957881   |   0.9928000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 6               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           6            |  0.09425293691456318   |         0.9916         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 7               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           7            |  0.08951396066695452   |         0.9924         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 8               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           8            |  0.09877728335559369   |         0.9916         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |               Training model 9               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           9            |  0.11177639309316874   |         0.9904         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 10               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           10           |   0.0791812926530838   |   0.9931999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 11               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           11           |  0.09234752561897039   |   0.9928000000000001   |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 12               |
# +----------------------------------------------+
# Epoch-13, Current Metric - 0.988:   0%|                                   | 0/4 [00:00<?, ? batch/s]
#
# No loss decrease after 5 epochs.
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           12           |  0.09685242809355259   |         0.9892         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 13               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           13           |  0.09739551693201065   |   0.9911999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 14               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           14           |  0.09635365176945924   |   0.9911999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 15               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           15           |   0.1239495448768139   |         0.9896         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 16               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           16           |  0.08558473400771618   |   0.9931999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 17               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           17           |  0.12080038636922837   |          0.99          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 18               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           18           |  0.09968951158225536   |         0.9916         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 19               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           19           |  0.10357228703796864   |   0.9908000000000001   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 20               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           20           |  0.10090529769659043   |   0.9911999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 21               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           21           |  0.11376947164535522   |          0.99          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 22               |
# +----------------------------------------------+
# Epoch-8, Current Metric - 0.992:   0%|                                    | 0/4 [00:00<?, ? batch/s]
#
# No loss decrease after 5 epochs.
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           22           |  0.09245709478855133   |   0.9911999999999999   |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 23               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           23           |   0.1099164467304945   |         0.9924         |
# +--------------------------------------------------------------------------+
# +----------------------------------------------+
# |              Training model 24               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           24           |  0.06862512547522784   |         0.994          |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 25               |
# +----------------------------------------------+
#
# No loss decrease after 5 epochs.
#
#
# Saving model.
# +--------------------------------------------------------------------------+
# |        Model ID        |          Loss          |      Metric Value      |
# +--------------------------------------------------------------------------+
# |           25           |  0.06787966266274452   |         0.9952         |
# +--------------------------------------------------------------------------+
#
#
# +----------------------------------------------+
# |              Training model 26               |
# +----------------------------------------------+
# Epoch-7, Current Metric - 0.994:  49%|███████████▊            | 230/465 [00:18<00:19, 12.11 batch/s]Time is out.
#
# No loss decrease after 30 epochs.
#
# 0.9937
